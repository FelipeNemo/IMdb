# %%
#Vamos importar as bibliotecas para trabalhar com o selenium. Precisamos importar um webdriver e o pacote ```By```, 
#que utilizaremos a seguir para definir a forma de busca dos elementos web.
from selenium import webdriver
from selenium.webdriver.common.by import By
from dataclasses import dataclass
import re
import json
import time

# %%
#Abaixo vamos inicializar uma sessão em um navegador Chrome utilizando o driver apropriado. Caso vá utilizar outro navegador, modifique o driver de acordo.
driver = webdriver.Chrome()
#O comando ```get()``` abaixo acessa a página web localizada no link passado como parâmetro no navegador.
driver.get("https://www.imdb.com")
driver.maximize_window()

# %%
#A função ```find_element()``` do Selenium encontra um elemento da árvore de acordo com algum tipo de localizador.
# ID = busca pelo atributo id
#    XPATH = busca pelo XPATH do elemento
#    LINK_TEXT = busca pelo texto de um link
#    PARTIAL_LINK_TEXT = busca pelo texto parcial de um link
#    NAME = busca pelo atributo "name"
#    TAG_NAME = busca pelo nome da tag
#    CLASS_NAME = busca pelo nome do atributo classe
#    CSS_SELECTOR = busca pelo nome do seletor CSS

#Lembrando que:
#-  ```'//'``` indica que o endereço inicia da raíz do objeto DOM
#- ```'*'``` indica que o elemento pode ter qualquer tag
#- ```'[@id="imdbHeader-navDrawerOpen"]'``` indica que o elemento deve possuir o atributo *id* com o valor *imdbHeader-navDrawerOpen*.
menu = driver.find_element(By.XPATH, r"//*[@id='imdbHeader-navDrawerOpen']")

# %%
#Podemos ver que o objeto retornado pela função ```find_element()``` é um objeto do tipo ```WebElement```,
#  uma classe implementada pela biblioteca Selenium para representar um elemento web html.
menu.tag_name
#Agora, vamos pedir para o driver realizar uma ação de clique no navegador no elemento que selecionamos.
menu.click()

# %%
#A função ```click()``` acima fez com que o menu fosse aberto no site, e, com isso, o código javascript ser executado dinamicamente 
#para gerar novos elementos web para criar os links no menu.
#Podemos agora procurar pelo elemento que armazena o link para página de filmes mais populares que queremos acessar.
#Desta vez, vamos utilizar como estratégia de localização o texto presente no link.
link_populares = driver.find_element(By.LINK_TEXT, "As 250 séries mais bem avaliadas")

# %%
#Podemos ver abaixo que a função ```find_element()``` retornou novamente um objeto ```WebElement```, 
#mas que agora que representa uma elemento do tipo *link* (TAG **a** do html).
link_populares.tag_name
#para a brir o link
url = link_populares.get_attribute("href")
#Com o link correto em mãos, podemos novamente pedir para o driver realizar uma ação no navegador e acessar a página de filmes mais populares.
driver.get(url)
tag_ul = driver.find_element(By.XPATH, r'//*[@id="__next"]/main/div/div[3]/section/div/div[2]/div/ul')
lista_series = tag_ul.find_elements(By.TAG_NAME, "li")

type(lista_series)
lista_series

for serie in lista_series:
    titulo =serie.find_element(By.CLASS_NAME, "ipc-title__text").text
    nota = serie.find_element(By.CLASS_NAME, "ipc-rating-star--rating").text#class="ipc-rating-star--rating"
    link = serie.find_element(By.CLASS_NAME, "ipc-title-link-wrapper").get_attribute("href")#<a href="/pt/title/tt0903747/?ref_=chttvtp_t_1" class="ipc-title-link-wrapper" tabindex="0"><h3 class="ipc-title__text ipc-title__text--reduced">1. Breaking Bad</h3></a>
    #Ano, Numero episodio e classificação indicada tem o mesmo metadata.
    #ano = serie.find_element(By.CLASS_NAME, "cli-title-metadata-item")[0].text#class="sc-15ac7568-7 cCsint cli-title-metadata-item"
    #numero_episodios= serie.find_element(By.CLASS_NAME, "cli-title-metadata-item")[1].text#class="sc-15ac7568-7 cCsint cli-title-metadata-item"
    #classificacao_indicada = serie.find_element(By.CLASS_NAME)
    diferenciar_atributos = serie.find_elements(By.CLASS_NAME, "cli-title-metadata-item")

    ano = None
    numero_episodios = None
    classificacao_indicada = None
    if len(diferenciar_atributos) > 0:
        ano = diferenciar_atributos[0].text
    if len(diferenciar_atributos) > 1:
        numero_episodios = diferenciar_atributos[1].text
    if len(diferenciar_atributos) > 2:
        classificacao_indicada = diferenciar_atributos[2].text

    print(f"{titulo} || Ano: {ano} || Nº Episódios: {numero_episodios} || Classificação: {classificacao_indicada} || Nota: {nota} || Link: {link}")
# Out:
# 1. Breaking Bad || Ano: 2008–2013 || Nº Episódios: 62 episódios || Classificação: 16 || Nota: 9,5 || Link: https://www.imdb.com/pt/title/tt0903747/?ref_=chttvtp_t_1
# 2. Planeta Terra II || Ano: 2016 || Nº Episódios: 6 episódios || Classificação: 10 || Nota: 9,4 || Link: https://www.imdb.com/pt/title/tt5491994/?ref_=chttvtp_t_2
# 3. Planeta Terra || Ano: 2006 || Nº Episódios: 11 episódios || Classificação: Livre || Nota: 9,4 || Link: https://www.imdb.com/pt/title/tt0795176/?ref_=chttvtp_t_3
# 4. Irmãos de Guerra || Ano: 2001 || Nº Episódios: 10 episódios || Classificação: 14 || Nota: 9,4 || Link: https://www.imdb.com/pt/title/tt0185906/?ref_=chttvtp_t_4
# 5. Chernobyl || Ano: 2019 || Nº Episódios: 5 episódios || Classificação: 16 || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt7366338/?ref_=chttvtp_t_5
# 6. A Escuta || Ano: 2002–2008 || Nº Episódios: 60 episódios || Classificação: 16 || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt0306414/?ref_=chttvtp_t_6
# 7. Avatar: A Lenda de Aang || Ano: 2005–2008 || Nº Episódios: 62 episódios || Classificação: Livre || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt0417299/?ref_=chttvtp_t_7
# 8. Família Soprano || Ano: 1999–2007 || Nº Episódios: 86 episódios || Classificação: 16 || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt0141842/?ref_=chttvtp_t_8
# 9. Planeta Azul II || Ano: 2017 || Nº Episódios: 7 episódios || Classificação: Livre || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt6769208/?ref_=chttvtp_t_9
# 10. Cosmos: Uma Odisseia do Espaço-Tempo || Ano: 2014 || Nº Episódios: 13 episódios || Classificação: Livre || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt2395695/?ref_=chttvtp_t_10
# 11. Cosmos || Ano: 1980 || Nº Episódios: 13 episódios || Classificação: Livre || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt0081846/?ref_=chttvtp_t_11
# 12. Nosso Planeta || Ano: 2019–2023 || Nº Episódios: 12 episódios || Classificação: 10 || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt9253866/?ref_=chttvtp_t_12
# 13. Game of Thrones || Ano: 2011–2019 || Nº Episódios: 74 episódios || Classificação: 16 || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt0944947/?ref_=chttvtp_t_13
# 14. Bluey || Ano: 2018– || Nº Episódios: 195 episódios || Classificação: Livre || Nota: 9,3 || Link: https://www.imdb.com/pt/title/tt7678620/?ref_=chttvtp_t_14
# 15. O Mundo em Guerra || Ano: 1973–1974 || Nº Episódios: 26 episódios || Classificação: TV-PG || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt0071075/?ref_=chttvtp_t_15
# 16. Fullmetal Alchemist: Brotherhood || Ano: 2009–2010 || Nº Episódios: 68 episódios || Classificação: 14 || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt1355642/?ref_=chttvtp_t_16
# 17. Vida || Ano: 2009 || Nº Episódios: 11 episódios || Classificação: Livre || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt1533395/?ref_=chttvtp_t_17
# 18. Attack on Titan || Ano: 2013–2023 || Nº Episódios: 98 episódios || Classificação: 18 || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt2560140/?ref_=chttvtp_t_18
# 19. Arremesso Final || Ano: 2020 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt8420184/?ref_=chttvtp_t_19
# 20. Rick e Morty || Ano: 2013– || Nº Episódios: 85 episódios || Classificação: 16 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt2861424/?ref_=chttvtp_t_20
# 21. Além da Imaginação || Ano: 1959–1964 || Nº Episódios: 156 episódios || Classificação: 12 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0052520/?ref_=chttvtp_t_21
# 22. A Guerra do Vietnã || Ano: 2017 || Nº Episódios: 10 episódios || Classificação: TV-MA || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt1877514/?ref_=chttvtp_t_22
# 23. Sherlock || Ano: 2010–2017 || Nº Episódios: 15 episódios || Classificação: 14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt1475582/?ref_=chttvtp_t_23
# 24. Batman: A Série Animada || Ano: 1992–1995 || Nº Episódios: 85 episódios || Classificação: Livre || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0103359/?ref_=chttvtp_t_24
# 25. Dexter: Ressurreição || Ano: 2025– || Nº Episódios: 11 episódios || Classificação: 18 || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt33043892/?ref_=chttvtp_t_25
# 26. Better Call Saul || Ano: 2015–2022 || Nº Episódios: 63 episódios || Classificação: 14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt3032476/?ref_=chttvtp_t_26
# 27. Arcane || Ano: 2021–2024 || Nº Episódios: 18 episódios || Classificação: 14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt11126994/?ref_=chttvtp_t_27
# 28. The Office - Vida de Escritório || Ano: 2005–2013 || Nº Episódios: 188 episódios || Classificação: 12 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0386676/?ref_=chttvtp_t_28
# 29. Planeta Azul || Ano: 2001 || Nº Episódios: 8 episódios || Classificação: Livre || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0296310/?ref_=chttvtp_t_29
# 30. Na Fazenda com Clarkson || Ano: 2021– || Nº Episódios: 33 episódios || Classificação: 12 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt10541088/?ref_=chttvtp_t_30
# 31. Scam 1992: The Harshad Mehta Story || Ano: 2020 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 9,2 || Link: https://www.imdb.com/pt/title/tt12392504/?ref_=chttvtp_t_31
# 32. Planeta Gelado || Ano: 2011–2012 || Nº Episódios: 10 episódios || Classificação: Livre || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt2092588/?ref_=chttvtp_t_32
# 33. Planeta Humano || Ano: 2011 || Nº Episódios: 8 episódios || Classificação: Livre || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt1806234/?ref_=chttvtp_t_33
# 34. Hunter x Hunter || Ano: 2011–2014 || Nº Episódios: 148 episódios || Classificação: 14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt2098220/?ref_=chttvtp_t_34
# 35. Only Fools and Horses || Ano: 1981–2003 || Nº Episódios: 64 episódios || Classificação: TV-PG || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0081912/?ref_=chttvtp_t_35
# 36. Firefly || Ano: 2002–2003 || Nº Episódios: 14 episódios || Classificação: TV-14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0303461/?ref_=chttvtp_t_36
# 37. The Civil War || Ano: 1990 || Nº Episódios: 9 episódios || Classificação: TV-14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0098769/?ref_=chttvtp_t_37
# 38. Death Note || Ano: 2006–2007 || Nº Episódios: 37 episódios || Classificação: 18 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0877057/?ref_=chttvtp_t_38
# 39. Gravity Falls: Um Verão de Mistérios || Ano: 2012–2016 || Nº Episódios: 41 episódios || Classificação: Livre || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt1865718/?ref_=chttvtp_t_39
# 40. Gibi || Ano: 2021–2025 || Nº Episódios: 68 episódios || Classificação: None || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt13675832/?ref_=chttvtp_t_40
# 41. The Pitt || Ano: 2025– || Nº Episódios: 30 episódios || Classificação: 14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt31938062/?ref_=chttvtp_t_41
# 42. Seinfeld || Ano: 1989–1998 || Nº Episódios: 172 episódios || Classificação: Livre || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0098904/?ref_=chttvtp_t_42
# 43. Decálogo || Ano: 1989–1990 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0092337/?ref_=chttvtp_t_43
# 44. The Beatles: Get Back || Ano: 2021 || Nº Episódios: 3 episódios || Classificação: Livre || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt9735318/?ref_=chttvtp_t_44
# 45. Cowboy Bebop || Ano: 1998–1999 || Nº Episódios: 26 episódios || Classificação: 16 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0213338/?ref_=chttvtp_t_45
# 46. Nathan for You || Ano: 2013–2017 || Nº Episódios: 32 episódios || Classificação: TV-14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt2297757/?ref_=chttvtp_t_46
# 47. True Detective || Ano: 2014– || Nº Episódios: 31 episódios || Classificação: 16 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt2356777/?ref_=chttvtp_t_47
# 48. Taskmaster || Ano: 2015– || Nº Episódios: 192 episódios || Classificação: TV-14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt4934214/?ref_=chttvtp_t_48
# 49. Fargo || Ano: 2014–2024 || Nº Episódios: 51 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt2802850/?ref_=chttvtp_t_49
# 50. Frieren e a Jornada para o Além || Ano: 2023– || Nº Episódios: 29 episódios || Classificação: TV-14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt22248376/?ref_=chttvtp_t_50
# 51. Sahsiyet || Ano: 2018–2024 || Nº Episódios: 22 episódios || Classificação: TV-MA || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt7920978/?ref_=chttvtp_t_51
# 52. Apocalipse: Redescobrindo a Segunda Guerra Mundial || Ano: 2009 || Nº Episódios: 6 episódios || Classificação: 16 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt1508238/?ref_=chttvtp_t_52
# 53. África || Ano: 2013 || Nº Episódios: 7 episódios || Classificação: Livre || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt2571774/?ref_=chttvtp_t_53
# 54. Olhos que Condenam || Ano: 2019 || Nº Episódios: 4 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt7137906/?ref_=chttvtp_t_54
# 55. Friends || Ano: 1994–2004 || Nº Episódios: 235 episódios || Classificação: 12 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0108778/?ref_=chttvtp_t_55
# 56. Last Week Tonight with John Oliver || Ano: 2014– || Nº Episódios: 395 episódios || Classificação: 14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt3530232/?ref_=chttvtp_t_56
# 57. It's Always Sunny in Philadelphia || Ano: 2005– || Nº Episódios: 178 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0472954/?ref_=chttvtp_t_57
# 58. West Wing: Nos Bastidores do Poder || Ano: 1999–2006 || Nº Episódios: 155 episódios || Classificação: 12 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0200276/?ref_=chttvtp_t_58
# 59. One Piece || Ano: 1999– || Nº Episódios: 1163 episódios || Classificação: 12 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0388629/?ref_=chttvtp_t_59
# 60. Succession || Ano: 2018–2023 || Nº Episódios: 39 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt7660850/?ref_=chttvtp_t_60
# 61. TVF Pitchers || Ano: 2015–2022 || Nº Episódios: 10 episódios || Classificação: TV-MA || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt4742876/?ref_=chttvtp_t_61
# 62. Segura a Onda || Ano: 2000–2024 || Nº Episódios: 120 episódios || Classificação: 14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0264235/?ref_=chttvtp_t_62
# 63. Monty Python's Flying Circus || Ano: 1969–1974 || Nº Episódios: 45 episódios || Classificação: 14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0063929/?ref_=chttvtp_t_63
# 64. SU-Boots: Submersos Em Guerras || Ano: 1985 || Nº Episódios: 3 episódios || Classificação: 14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0081834/?ref_=chttvtp_t_64
# 65. BoJack Horseman || Ano: 2014–2020 || Nº Episódios: 76 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt3398228/?ref_=chttvtp_t_65
# 66. Fawlty Towers || Ano: 1975–1979 || Nº Episódios: 12 episódios || Classificação: TV-PG || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0072500/?ref_=chttvtp_t_66
# 67. Bleach: Thousand-Year Blood War || Ano: 2022– || Nº Episódios: 41 episódios || Classificação: 12 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt14986406/?ref_=chttvtp_t_67
# 68. Panchayat || Ano: 2020– || Nº Episódios: 32 episódios || Classificação: 14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt12004706/?ref_=chttvtp_t_68
# 69. Se a Vida te Der Tangerinas... || Ano: 2025 || Nº Episódios: 16 episódios || Classificação: TV-14 || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt26471411/?ref_=chttvtp_t_69
# 70. Dragon Ball Z || Ano: 1996–2003 || Nº Episódios: 277 episódios || Classificação: 12 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0214341/?ref_=chttvtp_t_70
# 71. Blackadder Goes Forth || Ano: 1989 || Nº Episódios: 6 episódios || Classificação: TV-PG || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0096548/?ref_=chttvtp_t_71
# 72. The Chosen - Os Escolhidos || Ano: 2017– || Nº Episódios: 44 episódios || Classificação: 16 || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt5622316/?ref_=chttvtp_t_72
# 73. Leyla e Mecnun || Ano: 2011–2023 || Nº Episódios: 144 episódios || Classificação: TV-PG || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt1831164/?ref_=chttvtp_t_73
# 74. Freaks & Geeks || Ano: 1999–2000 || Nº Episódios: 18 episódios || Classificação: 12 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0193676/?ref_=chttvtp_t_74
# 75. Dragon Ball Z || Ano: 1989–1996 || Nº Episódios: 291 episódios || Classificação: 12 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0121220/?ref_=chttvtp_t_75
# 76. Orgulho e Preconceito || Ano: 1995 || Nº Episódios: 6 episódios || Classificação: Livre || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0112130/?ref_=chttvtp_t_76
# 77. Vinland Saga || Ano: 2019–2023 || Nº Episódios: 48 episódios || Classificação: 18 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt10233448/?ref_=chttvtp_t_77
# 78. Gullak || Ano: 2019– || Nº Episódios: 20 episódios || Classificação: None || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt10530900/?ref_=chttvtp_t_78
# 79. Twin Peaks || Ano: 1990–1991 || Nº Episódios: 30 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0098936/?ref_=chttvtp_t_79
# 80. Chappelle's Show || Ano: 2003–2006 || Nº Episódios: 33 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0353049/?ref_=chttvtp_t_80
# 81. Narcos || Ano: 2015–2017 || Nº Episódios: 30 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt2707408/?ref_=chttvtp_t_81
# 82. Eu, Cláudio || Ano: 1976 || Nº Episódios: 13 episódios || Classificação: Not Rated || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0074006/?ref_=chttvtp_t_82
# 83. South Park || Ano: 1997– || Nº Episódios: 335 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0121955/?ref_=chttvtp_t_83
# 84. Responde 1988 || Ano: 2015–2016 || Nº Episódios: 20 episódios || Classificação: None || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt5182866/?ref_=chttvtp_t_84
# 85. A Fábrica de Kota || Ano: 2019–2021 || Nº Episódios: 15 episódios || Classificação: Livre || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt9432978/?ref_=chttvtp_t_85
# 86. Ted Lasso || Ano: 2020– || Nº Episódios: 44 episódios || Classificação: 14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt10986410/?ref_=chttvtp_t_86
# 87. O Segredo Além do Jardim || Ano: 2014 || Nº Episódios: 10 episódios || Classificação: 10 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt3718778/?ref_=chttvtp_t_87
# 88. Black Mirror || Ano: 2011– || Nº Episódios: 33 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt2085059/?ref_=chttvtp_t_88
# 89. Meu Companheiro || Ano: 2018 || Nº Episódios: 16 episódios || Classificação: 16 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt7923710/?ref_=chttvtp_t_89
# 90. Steins;Gate || Ano: 2011–2015 || Nº Episódios: 26 episódios || Classificação: 12 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt1910272/?ref_=chttvtp_t_90
# 91. Peaky Blinders: Sangue, Apostas e Navalhas || Ano: 2013–2022 || Nº Episódios: 36 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt2442560/?ref_=chttvtp_t_91
# 92. Berserk || Ano: 1997–1998 || Nº Episódios: 25 episódios || Classificação: 16+ || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0318871/?ref_=chttvtp_t_92
# 93. A Sete Palmos || Ano: 2001–2005 || Nº Episódios: 63 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0248654/?ref_=chttvtp_t_93
# 94. Roma || Ano: 2005–2007 || Nº Episódios: 22 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0384766/?ref_=chttvtp_t_94
# 95. Oz || Ano: 1997–2003 || Nº Episódios: 56 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0118421/?ref_=chttvtp_t_95
# 96. X-Men '97 || Ano: 2024– || Nº Episódios: 12 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt16026746/?ref_=chttvtp_t_96
# 97. Dark || Ano: 2017–2020 || Nº Episódios: 26 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt5753856/?ref_=chttvtp_t_97
# 98. Fleabag || Ano: 2016–2019 || Nº Episódios: 12 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt5687612/?ref_=chttvtp_t_98
# 99. Downton Abbey || Ano: 2010–2015 || Nº Episódios: 52 episódios || Classificação: 12 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt1606375/?ref_=chttvtp_t_99
# 100. The Shield: Acima da Lei || Ano: 2002–2008 || Nº Episódios: 89 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0286486/?ref_=chttvtp_t_100
# 101. The Grand Tour || Ano: 2016–2024 || Nº Episódios: 46 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt5712554/?ref_=chttvtp_t_101
# 102. Battlestar Galactica || Ano: 2004–2009 || Nº Episódios: 74 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0407362/?ref_=chttvtp_t_102
# 103. Monster || Ano: 2004–2005 || Nº Episódios: 75 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0434706/?ref_=chttvtp_t_103
# 104. Peep Show || Ano: 2003–2015 || Nº Episódios: 54 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0387764/?ref_=chttvtp_t_104
# 105. Naruto Shippuden || Ano: 2007–2017 || Nº Episódios: 501 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0988824/?ref_=chttvtp_t_105
# 106. Mad Men: Inventando Verdades || Ano: 2007–2015 || Nº Episódios: 92 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0804503/?ref_=chttvtp_t_106
# 107. Samurai de Olhos Azuis || Ano: 2023– || Nº Episódios: 9 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt13309742/?ref_=chttvtp_t_107
# 108. Invencível || Ano: 2021– || Nº Episódios: 26 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt6741278/?ref_=chttvtp_t_108
# 109. Jornada nas Estrelas: A Nova Geração || Ano: 1987–1994 || Nº Episódios: 176 episódios || Classificação: Livre || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0092455/?ref_=chttvtp_t_109
# 110. Os Simpsons || Ano: 1989– || Nº Episódios: 856 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0096697/?ref_=chttvtp_t_110
# 111. Ruptura || Ano: 2022– || Nº Episódios: 20 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt11280740/?ref_=chttvtp_t_111
# 112. Dr. House || Ano: 2004–2012 || Nº Episódios: 176 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0412142/?ref_=chttvtp_t_112
# 113. Liga da Justiça sem Limites || Ano: 2004–2006 || Nº Episódios: 39 episódios || Classificação: Livre || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt6025022/?ref_=chttvtp_t_113
# 114. The Adventures of Sherlock Holmes || Ano: 1984–1985 || Nº Episódios: 13 episódios || Classificação: TV-PG || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0086661/?ref_=chttvtp_t_114
# 115. Arrested Development || Ano: 2003–2019 || Nº Episódios: 84 episódios || Classificação: Livre || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0367279/?ref_=chttvtp_t_115
# 116. Mahabharat || Ano: 1988–1990 || Nº Episódios: 94 episódios || Classificação: TV-14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt0158417/?ref_=chttvtp_t_116
# 117. One Punch Man || Ano: 2015– || Nº Episódios: 39 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4508902/?ref_=chttvtp_t_117
# 118. Line of Duty || Ano: 2012–2026 || Nº Episódios: 37 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt2303687/?ref_=chttvtp_t_118
# 119. Friday Night Lights || Ano: 2006–2011 || Nº Episódios: 76 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0758745/?ref_=chttvtp_t_119
# 120. Top Gear || Ano: 2002–2022 || Nº Episódios: 328 episódios || Classificação: Livre || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt1628033/?ref_=chttvtp_t_120
# 121. Maravilhosa Sra. Maisel || Ano: 2017–2023 || Nº Episódios: 43 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt5788792/?ref_=chttvtp_t_121
# 122. How to with John Wilson || Ano: 2020–2023 || Nº Episódios: 18 episódios || Classificação: Livre || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt10801534/?ref_=chttvtp_t_122
# 123. Stranger Things || Ano: 2016–2025 || Nº Episódios: 42 episódios || Classificação: 14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4574334/?ref_=chttvtp_t_123
# 124. The Boys || Ano: 2019– || Nº Episódios: 40 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1190634/?ref_=chttvtp_t_124
# 125. The Thick of It || Ano: 2005–2012 || Nº Episódios: 24 episódios || Classificação: TV-MA || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0459159/?ref_=chttvtp_t_125
# 126. This Is Us: Histórias de Família || Ano: 2016–2022 || Nº Episódios: 106 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt5555260/?ref_=chttvtp_t_126
# 127. Aspirants || Ano: 2021– || Nº Episódios: 10 episódios || Classificação: None || Nota: 9,1 || Link: https://www.imdb.com/pt/title/tt14392248/?ref_=chttvtp_t_127
# 128. Ramayan || Ano: 1987–1988 || Nº Episódios: 78 episódios || Classificação: TV-14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt0268093/?ref_=chttvtp_t_128
# 129. Code Geass: Lelouch of the Rebellion || Ano: 2006–2008 || Nº Episódios: 54 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0994314/?ref_=chttvtp_t_129
# 130. Father Ted || Ano: 1995–1998 || Nº Episódios: 25 episódios || Classificação: TV-14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0111958/?ref_=chttvtp_t_130
# 131. 1883 || Ano: 2021–2022 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt13991232/?ref_=chttvtp_t_131
# 132. Behzat Ç. || Ano: 2010–2019 || Nº Episódios: 105 episódios || Classificação: TV-14 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt1795096/?ref_=chttvtp_t_132
# 133. Hora de Aventura || Ano: 2010–2018 || Nº Episódios: 289 episódios || Classificação: 10 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1305826/?ref_=chttvtp_t_133
# 134. Dexter || Ano: 2006–2013 || Nº Episódios: 96 episódios || Classificação: 18 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0773262/?ref_=chttvtp_t_134
# 135. Parks and Recreation || Ano: 2009–2015 || Nº Episódios: 124 episódios || Classificação: Livre || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1266020/?ref_=chttvtp_t_135
# 136. Arquivo X || Ano: 1993–2018 || Nº Episódios: 217 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0106179/?ref_=chttvtp_t_136
# 137. Sarabhai V/S Sarabhai || Ano: 2004–2017 || Nº Episódios: 79 episódios || Classificação: TV-PG || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt1518542/?ref_=chttvtp_t_137
# 138. Mr Inbetween || Ano: 2018–2021 || Nº Episódios: 26 episódios || Classificação: 18 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt7472896/?ref_=chttvtp_t_138
# 139. Atlanta || Ano: 2016–2022 || Nº Episódios: 41 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4288182/?ref_=chttvtp_t_139
# 140. Hajime no Ippo || Ano: 2000–2002 || Nº Episódios: 76 episódios || Classificação: 12 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt0481256/?ref_=chttvtp_t_140
# 141. Deadwood: Cidade sem Lei || Ano: 2004–2006 || Nº Episódios: 36 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0348914/?ref_=chttvtp_t_141
# 142. The Mandalorian || Ano: 2019– || Nº Episódios: 25 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt8111088/?ref_=chttvtp_t_142
# 143. House of Cards || Ano: 2013–2018 || Nº Episódios: 73 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1856010/?ref_=chttvtp_t_143
# 144. The Crown || Ano: 2016–2023 || Nº Episódios: 60 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4786824/?ref_=chttvtp_t_144
# 145. Demolidor || Ano: 2015–2018 || Nº Episódios: 39 episódios || Classificação: 18 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt3322312/?ref_=chttvtp_t_145
# 146. It's a Sin || Ano: 2021 || Nº Episódios: 5 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt9140342/?ref_=chttvtp_t_146
# 147. The Bridge || Ano: 2011–2018 || Nº Episódios: 38 episódios || Classificação: 14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1733785/?ref_=chttvtp_t_147
# 148. Poirot || Ano: 1989–2013 || Nº Episódios: 70 episódios || Classificação: TV-14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0094525/?ref_=chttvtp_t_148
# 149. Primal || Ano: 2019– || Nº Episódios: 21 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt10332508/?ref_=chttvtp_t_149
# 150. Mindhunter || Ano: 2017–2019 || Nº Episódios: 19 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt5290382/?ref_=chttvtp_t_150
# 151. Blackadder II || Ano: 1986 || Nº Episódios: 6 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0088484/?ref_=chttvtp_t_151
# 152. Os Pistoleiros do Oeste || Ano: 1989 || Nº Episódios: 4 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0096639/?ref_=chttvtp_t_152
# 153. Mr. Bean || Ano: 1990–1995 || Nº Episódios: 15 episódios || Classificação: 10 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0096657/?ref_=chttvtp_t_153
# 154. Xógum: A Gloriosa Saga do Japão || Ano: 2024–2026 || Nº Episódios: 12 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt2788316/?ref_=chttvtp_t_154
# 155. Haikyu!! || Ano: 2014–2020 || Nº Episódios: 89 episódios || Classificação: 10 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt3398540/?ref_=chttvtp_t_155
# 156. The Offer || Ano: 2022 || Nº Episódios: 10 episódios || Classificação: 18 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt13111040/?ref_=chttvtp_t_156
# 157. The Return of Sherlock Holmes || Ano: 1986–1988 || Nº Episódios: 11 episódios || Classificação: TV-PG || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0090509/?ref_=chttvtp_t_157
# 158. Pose || Ano: 2018–2021 || Nº Episódios: 26 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt7562112/?ref_=chttvtp_t_158
# 159. Chaves || Ano: 1972–1983 || Nº Episódios: 358 episódios || Classificação: Livre || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0229889/?ref_=chttvtp_t_159
# 160. Pousando no Amor || Ano: 2019–2020 || Nº Episódios: 19 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt10850932/?ref_=chttvtp_t_160
# 161. Pinguim || Ano: 2024 || Nº Episódios: 8 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt15435876/?ref_=chttvtp_t_161
# 162. Yes Minister || Ano: 1980–1984 || Nº Episódios: 22 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0080306/?ref_=chttvtp_t_162
# 163. Gomorra: La serie || Ano: 2014–2021 || Nº Episódios: 58 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt2049116/?ref_=chttvtp_t_163
# 164. The Jinx: A Vida e as Mortes de Robert Durst || Ano: 2015–2024 || Nº Episódios: 12 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4299972/?ref_=chttvtp_t_164
# 165. Le Bureau des Légendes || Ano: 2015–2020 || Nº Episódios: 50 episódios || Classificação: TV-MA || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt4063800/?ref_=chttvtp_t_165
# 166. Blackadder the Third || Ano: 1987 || Nº Episódios: 6 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0092324/?ref_=chttvtp_t_166
# 167. Grandes Momentos da Segunda Guerra em Cores || Ano: 2019 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt9103932/?ref_=chttvtp_t_167
# 168. Planeta dos Abutres || Ano: 2023 || Nº Episódios: 12 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt21056886/?ref_=chttvtp_t_168
# 169. Anne com um E || Ano: 2017–2019 || Nº Episódios: 27 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt5421602/?ref_=chttvtp_t_169
# 170. The Newsroom || Ano: 2012–2014 || Nº Episódios: 25 episódios || Classificação: 14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1870479/?ref_=chttvtp_t_170
# 171. Homicídio || Ano: 1993–1999 || Nº Episódios: 122 episódios || Classificação: TV-14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0106028/?ref_=chttvtp_t_171
# 172. Boardwalk Empire: O Império do Contrabando || Ano: 2010–2014 || Nº Episódios: 56 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0979432/?ref_=chttvtp_t_172
# 173. Critical Role || Ano: 2015– || Nº Episódios: 379 episódios || Classificação: TV-14 || Nota: 9,0 || Link: https://www.imdb.com/pt/title/tt4834232/?ref_=chttvtp_t_173
# 174. Archer || Ano: 2009–2023 || Nº Episódios: 143 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1486217/?ref_=chttvtp_t_174
# 175. Dopesick || Ano: 2021 || Nº Episódios: 8 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt9174558/?ref_=chttvtp_t_175
# 176. Andor || Ano: 2022–2025 || Nº Episódios: 24 episódios || Classificação: 14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt9253284/?ref_=chttvtp_t_176
# 177. Yeh Meri Family || Ano: 2018– || Nº Episódios: 22 episódios || Classificação: TV-14 || Nota: 8,9 || Link: https://www.imdb.com/pt/title/tt8595766/?ref_=chttvtp_t_177
# 178. Mystery Science Theater 3000 || Ano: 1988–1999 || Nº Episódios: 199 episódios || Classificação: TV-14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0094517/?ref_=chttvtp_t_178
# 179. Justificado || Ano: 2010–2015 || Nº Episódios: 78 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1489428/?ref_=chttvtp_t_179
# 180. O Show do Pernalonga || Ano: 1960–1975 || Nº Episódios: 78 episódios || Classificação: Livre || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0053488/?ref_=chttvtp_t_180
# 181. Homem de Família || Ano: 2019– || Nº Episódios: 20 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt9544034/?ref_=chttvtp_t_181
# 182. QI || Ano: 2003– || Nº Episódios: 358 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0380136/?ref_=chttvtp_t_182
# 183. Justiça Jovem || Ano: 2010–2022 || Nº Episódios: 98 episódios || Classificação: 10 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1641384/?ref_=chttvtp_t_183
# 184. Demon Slayer: Kimetsu no Yaiba || Ano: 2019–2024 || Nº Episódios: 63 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt9335498/?ref_=chttvtp_t_184
# 185. O Que Fazemos nas Sombras || Ano: 2019–2024 || Nº Episódios: 61 episódios || Classificação: 14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt7908628/?ref_=chttvtp_t_185
# 186. Battlestar Galactica || Ano: 2003 || Nº Episódios: 2 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0314979/?ref_=chttvtp_t_186
# 187. Dragon Ball || Ano: 1986–1989 || Nº Episódios: 153 episódios || Classificação: 12 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0088509/?ref_=chttvtp_t_187
# 188. Liga da Justiça || Ano: 2001–2004 || Nº Episódios: 52 episódios || Classificação: Livre || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0275137/?ref_=chttvtp_t_188
# 189. A Maldição da Residência Hill || Ano: 2018 || Nº Episódios: 10 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt6763664/?ref_=chttvtp_t_189
# 190. Endeavour || Ano: 2012–2023 || Nº Episódios: 36 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt2701582/?ref_=chttvtp_t_190
# 191. Dragon Ball || Ano: 1995–2003 || Nº Episódios: 153 episódios || Classificação: Livre || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0280249/?ref_=chttvtp_t_191
# 192. Yes, Prime Minister || Ano: 1986–1987 || Nº Episódios: 16 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0086831/?ref_=chttvtp_t_192
# 193. Os Irmãos Aventura || Ano: 2003–2018 || Nº Episódios: 86 episódios || Classificação: TV-14 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0417373/?ref_=chttvtp_t_193
# 194. Samurai Champloo || Ano: 2004–2005 || Nº Episódios: 26 episódios || Classificação: TV-MA || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0423731/?ref_=chttvtp_t_194
# 195. Flight of the Conchords || Ano: 2007–2009 || Nº Episódios: 22 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0863046/?ref_=chttvtp_t_195
# 196. O Ensaio || Ano: 2022– || Nº Episódios: 12 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt10802170/?ref_=chttvtp_t_196
# 197. Sol Negro || Ano: 2017–2020 || Nº Episódios: 20 episódios || Classificação: 16 || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt6108262/?ref_=chttvtp_t_197
# 198. The IT Crowd || Ano: 2006–2013 || Nº Episódios: 25 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0487831/?ref_=chttvtp_t_198
# 199. O Gambito da Rainha || Ano: 2020 || Nº Episódios: 7 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt10048342/?ref_=chttvtp_t_199
# 200. Coupling || Ano: 2000–2004 || Nº Episódios: 28 episódios || Classificação: TV-14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0237123/?ref_=chttvtp_t_200
# 201. Mr. Robot: Sociedade Hacker || Ano: 2015–2019 || Nº Episódios: 45 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt4158110/?ref_=chttvtp_t_201
# 202. Rocket Boys || Ano: 2022– || Nº Episódios: 16 episódios || Classificação: None || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt13868972/?ref_=chttvtp_t_202
# 203. I'm Alan Partridge || Ano: 1997–2002 || Nº Episódios: 12 episódios || Classificação: TV-MA || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0129690/?ref_=chttvtp_t_203
# 204. Samurai Jack || Ano: 2001–2017 || Nº Episódios: 62 episódios || Classificação: Livre || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0278238/?ref_=chttvtp_t_204
# 205. Detectoristas || Ano: 2014–2022 || Nº Episódios: 20 episódios || Classificação: 10 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4082744/?ref_=chttvtp_t_205
# 206. Apenas um Show || Ano: 2010–2017 || Nº Episódios: 244 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1710308/?ref_=chttvtp_t_206
# 207. Ezel || Ano: 2009–2011 || Nº Episódios: 71 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1534360/?ref_=chttvtp_t_207
# 208. Making a Murderer || Ano: 2015–2018 || Nº Episódios: 20 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt5189670/?ref_=chttvtp_t_208
# 209. Happy Valley || Ano: 2014–2023 || Nº Episódios: 18 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt3428912/?ref_=chttvtp_t_209
# 210. Em Duas Rodas com Ewan McGregor || Ano: 2004–2010 || Nº Episódios: 10 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0403778/?ref_=chttvtp_t_210
# 211. Solo Leveling || Ano: 2024– || Nº Episódios: 26 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt21209876/?ref_=chttvtp_t_211
# 212. The Last of Us || Ano: 2023– || Nº Episódios: 17 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt3581920/?ref_=chttvtp_t_212
# 213. Derry Girls || Ano: 2018–2022 || Nº Episódios: 19 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt7120662/?ref_=chttvtp_t_213
# 214. Spaced || Ano: 1999–2001 || Nº Episódios: 14 episódios || Classificação: TV-14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0187664/?ref_=chttvtp_t_214
# 215. Tirando a Maior Onda || Ano: 2011– || Nº Episódios: 320 episódios || Classificação: 12 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt2100976/?ref_=chttvtp_t_215
# 216. Mob Psycho 100 || Ano: 2016–2022 || Nº Episódios: 37 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt5897304/?ref_=chttvtp_t_216
# 217. Twin Peaks || Ano: 2017 || Nº Episódios: 18 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt4093826/?ref_=chttvtp_t_217
# 218. Filhos da Anarquia || Ano: 2008–2014 || Nº Episódios: 92 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt1124373/?ref_=chttvtp_t_218
# 219. Whose Line Is It Anyway? || Ano: 1998–2007 || Nº Episódios: 220 episódios || Classificação: TV-PG || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0163507/?ref_=chttvtp_t_219
# 220. Yellowstone || Ano: 2018–2024 || Nº Episódios: 53 episódios || Classificação: 18 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt4236770/?ref_=chttvtp_t_220
# 221. Mind Your Language || Ano: 1977–1986 || Nº Episódios: 42 episódios || Classificação: 10 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0075537/?ref_=chttvtp_t_221
# 222. The Eric Andre Show || Ano: 2012– || Nº Episódios: 68 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt2244495/?ref_=chttvtp_t_222
# 223. Louie || Ano: 2010–2015 || Nº Episódios: 61 episódios || Classificação: TV-MA || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt1492966/?ref_=chttvtp_t_223
# 224. O Urso || Ano: 2022– || Nº Episódios: 39 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt14452776/?ref_=chttvtp_t_224
# 225. Neon Genesis Evangelion || Ano: 1995–1996 || Nº Episódios: 26 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0112159/?ref_=chttvtp_t_225
# 226. Jujutsu Kaisen || Ano: 2020– || Nº Episódios: 48 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt12343534/?ref_=chttvtp_t_226
# 227. Através do Buraco de Minhoca || Ano: 2010–2017 || Nº Episódios: 62 episódios || Classificação: L || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1513168/?ref_=chttvtp_t_227
# 228. The Office || Ano: 2001–2003 || Nº Episódios: 14 episódios || Classificação: 12 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0290978/?ref_=chttvtp_t_228
# 229. Alquimia das Almas || Ano: 2022–2023 || Nº Episódios: 30 episódios || Classificação: 14 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt20859920/?ref_=chttvtp_t_229
# 230. Trailer Park Boys || Ano: 2001–2026 || Nº Episódios: 116 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0290988/?ref_=chttvtp_t_230
# 231. A Amiga Genial || Ano: 2018–2024 || Nº Episódios: 34 episódios || Classificação: 16 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt7278862/?ref_=chttvtp_t_231
# 232. Criaturas Grandes e Pequenas || Ano: 2020– || Nº Episódios: 38 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt10590066/?ref_=chttvtp_t_232
# 233. Schitt's Creek || Ano: 2015–2020 || Nº Episódios: 80 episódios || Classificação: 16 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt3526078/?ref_=chttvtp_t_233
# 234. Silicon Valley || Ano: 2014–2019 || Nº Episódios: 53 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt2575988/?ref_=chttvtp_t_234
# 235. Brass Eye || Ano: 1997–2001 || Nº Episódios: 7 episódios || Classificação: TV-MA || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0118273/?ref_=chttvtp_t_235
# 236. The Expanse || Ano: 2015–2022 || Nº Episódios: 62 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt3230854/?ref_=chttvtp_t_236
# 237. Futurama || Ano: 1999– || Nº Episódios: 180 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0149460/?ref_=chttvtp_t_237
# 238. Fullmetal Alchemist || Ano: 2003–2004 || Nº Episódios: 51 episódios || Classificação: 12 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0421357/?ref_=chttvtp_t_238
# 239. Rurôni Kenshin: Meiji kenkaku romantan - Tsuioku-hen || Ano: 1999 || Nº Episódios: 4 episódios || Classificação: TV-MA || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0203082/?ref_=chttvtp_t_239
# 240. Avrupa Yakasi || Ano: 2004–2009 || Nº Episódios: 190 episódios || Classificação: None || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt0421291/?ref_=chttvtp_t_240
# 241. Hannibal || Ano: 2013–2015 || Nº Episódios: 39 episódios || Classificação: 18 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt2243973/?ref_=chttvtp_t_241
# 242. O Pecado Original de Takopi || Ano: 2025 || Nº Episódios: 6 episódios || Classificação: Approved || Nota: 8,8 || Link: https://www.imdb.com/pt/title/tt36988358/?ref_=chttvtp_t_242
# 243. Gintama || Ano: 2005–2021 || Nº Episódios: 375 episódios || Classificação: 16 || Nota: 8,7 || Link: https://www.imdb.com/pt/title/tt0988818/?ref_=chttvtp_t_243
# 244. Skam || Ano: 2015–2017 || Nº Episódios: 43 episódios || Classificação: 12 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt5288312/?ref_=chttvtp_t_244
# 245. Shameless || Ano: 2011–2021 || Nº Episódios: 134 episódios || Classificação: 18 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt1586680/?ref_=chttvtp_t_245
# 246. North & South || Ano: 2004 || Nº Episódios: 4 episódios || Classificação: Livre || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0417349/?ref_=chttvtp_t_246
# 247. The Great British Bake Off || Ano: 2010– || Nº Episódios: 195 episódios || Classificação: TV-PG || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt1877368/?ref_=chttvtp_t_247
# 248. Doctor Who || Ano: 2005–2022 || Nº Episódios: 175 episódios || Classificação: 10 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt0436992/?ref_=chttvtp_t_248
# 249. Wentworth - Por Trás das Grades || Ano: 2013–2021 || Nº Episódios: 100 episódios || Classificação: 18 || Nota: 8,6 || Link: https://www.imdb.com/pt/title/tt2433738/?ref_=chttvtp_t_249
# 250. Fórmula 1: Dirigir para Viver || Ano: 2019– || Nº Episódios: 71 episódios || Classificação: 14 || Nota: 8,5 || Link: https://www.imdb.com/pt/title/tt8289930/?ref_=chttvtp_t_250

# %%
link_populares.tag_name
url = link_populares.get_attribute("href")
driver.get(url)
tag_ul = driver.find_element(By.XPATH, r'//*[@id="__next"]/main/div/div[3]/section/div/div[2]/div/ul')
lista_series = tag_ul.find_elements(By.TAG_NAME, "li")

type(lista_series)
lista_series

for serie in lista_series:
    titulo =serie.find_element(By.CLASS_NAME, "ipc-title__text").text
    link = serie.find_element(By.CLASS_NAME, "ipc-title-link-wrapper").get_attribute("href")
    nota = serie.find_element(By.CLASS_NAME, "ipc-rating-star--rating").text

    popularidade = None
    pop_elem = driver.find_elements(By.XPATH, "//*[contains(text(),'Popularidade')]")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 11
#       8 detalhes_series = []
#      10 for link in links_series[:50]:  # depois troca para [:250]
# ---> 11     driver.get(link)
#      12     time.sleep(1)
#      14     # --- Título e nota ---
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\selenium\webdriver\remote\webdriver.py:483, in WebDriver.get(self, url)
#     465 def get(self, url: str) -> None:
#     466     """Navigate the browser to the specified URL in the current window or
#     467     tab.
#     468
#    (...)    481     >>> driver.get("https://example.com")
#     482     """
# --> 483     self.execute(Command.GET, {"url": url})
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:406, in RemoteConnection.execute(self, command, params)
#     404 trimmed = self._trim_large_entries(params)
#     405 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 406 return self._request(command_info[0], url, body=data)
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:430, in RemoteConnection._request(self, method, url, body)
#     427     body = None
#     429 if self._client_config.keep_alive:
# --> 430     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     431     statuscode = response.status
#     432 else:
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\ThF\miniconda3\envs\chinelagem\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Importaremos a biblioteca ```dataclasses``` para usar o decorador ```@dataclass```, que irá adicionar alguns métodos automaticamente, como o construtor de classe.
from dataclasses import dataclass
@dataclass
class Serie:
    titulo: str
    ano: str
    classificacao: float
    pagina: str

# %%
#Vamos precisar utilizar uma regex (expressão regular) para extrair apenas o valor da nota do filme.
#biblioteca para expressões regulares
import re

def cria_filme(imdb_li_tag):
    titulo = imdb_li_tag.find_element(By.CLASS_NAME, "ipc-title__text").text #pegamos o texto do elemento
    ano = imdb_li_tag.find_element(By.XPATH, r'./div/div/div/div/div[2]/div[2]/span[1]').text 
    texto_classificacao = imdb_li_tag.find_element(By.CLASS_NAME, "ipc-rating-star").text #este texto está 'sujo', contém o número de votos também
    pagina = imdb_li_tag.find_element(By.CLASS_NAME, "ipc-title-link-wrapper").get_attribute("href")
    re_result = re.search(r'^\d\,\d',texto_classificacao) #aplicando a regex para extrair apenas o padrão 'digito ponto digito'
    
    classificacao = None
    if re_result:
        classificacao = re.search(r'^\d\,\d',texto_classificacao).group(0) #string resultante da regex
        classificacao = float(classificacao.replace(",", ".")) # Aletera o separador decimal
        
    return Filme(titulo, ano, classificacao, pagina)

# %%
#Vamos agora criar uma lista contendo todos os filmes que extraímos da página. 
#Para isto, vamos utilizar uma estrutura de lista em Python, a classe ```Filme``` e o méotodo ```cria_filme``` que criamos.
lista_de_filmes = []

for filme_tag in lista_filmes:
    # título
    titulo = filme_tag.find_element(By.CLASS_NAME, "ipc-title__text").text  

    # ano (primeiro span de metadata)
    ano = filme_tag.find_element(By.CSS_SELECTOR, ".cli-title-metadata-item").text  

    # classificação (nota do IMDb)
    classificacao = filme_tag.find_element(By.CLASS_NAME, "ipc-rating-star").text  

    # link da página do filme
    pagina = filme_tag.find_element(By.CLASS_NAME, "ipc-title-link-wrapper").get_attribute("href")

    lista_de_filmes.append({
        "titulo": titulo,
        "ano": ano,
        "classificacao": classificacao,
        "pagina": pagina
    })

# exemplo: imprimir os 10 primeiros
for filme in lista_de_filmes[:10]:
    print(filme)
# Out:
# {'titulo': 'Superman', 'ano': '2025', 'classificacao': '7,2\n (304 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt5950044/?ref_=chtmvm_t_1'}
# {'titulo': 'A Hora do Mal', 'ano': '2025', 'classificacao': '7,6\n (158 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt26581740/?ref_=chtmvm_t_2'}
# {'titulo': 'A Longa Marcha - Caminhe ou Morra', 'ano': '2025', 'classificacao': '7,3\n (21 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt10374610/?ref_=chtmvm_t_3'}
# {'titulo': 'Uma Batalha Após a Outra', 'ano': '2025', 'classificacao': '8,6\n (8,1 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt30144839/?ref_=chtmvm_t_4'}
# {'titulo': 'GOAT', 'ano': '2025', 'classificacao': '5,4\n (4,3 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt20990442/?ref_=chtmvm_t_5'}
# {'titulo': 'Demon Slayer: Kimetsu no Yaiba - Castelo Infinito', 'ano': '2025', 'classificacao': '8,6\n (37 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt32820897/?ref_=chtmvm_t_6'}
# {'titulo': 'Invocação do Mal 4: O Último Ritual', 'ano': '2025', 'classificacao': '6,4\n (37 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt22898462/?ref_=chtmvm_t_7'}
# {'titulo': 'Extermínio: A Evolução', 'ano': '2025', 'classificacao': '6,7\n (136 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt10548174/?ref_=chtmvm_t_8'}
# {'titulo': 'Anaconda', 'ano': '2025', 'classificacao': '', 'pagina': 'https://www.imdb.com/pt/title/tt33244668/?ref_=chtmvm_t_9'}
# {'titulo': 'A Grande Viagem da Sua Vida', 'ano': '2025', 'classificacao': '6,1\n (3,9 mil)', 'pagina': 'https://www.imdb.com/pt/title/tt13650700/?ref_=chtmvm_t_10'}

# %%
#Vamos agora armazenar nossa lista de filmes em um objeto JSON e salvar em um arquivo.

#Precisaremos importar a biblioteca ```json``` 
#e converter nosso objeto ```Filme``` para um dicionário, pois é o tipo de estrutura de dados aceita pela função ```dump()```.
#O arquivo será salvo na mesma pasta em que o notebook está sendo executado.
import json

with open("filmes.json", "w", encoding="utf-8") as arquivo:
    json.dump(lista_de_filmes, arquivo, ensure_ascii=False, indent=4)

# fechar o navegador
driver.quit()
